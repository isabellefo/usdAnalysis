# %% [markdown]
# # EP2 MASANORI

# %% [markdown]
# ## Authors:
# ### Gabriel Borges
# ### Isabelle Oliveira

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfusd = pd.read_csv('daily.csv')

# %%
dfbtc = pd.read_csv('bitcoin_price.csv')

# %%
listC = list(set(dfusd.loc[:,'Country']))[:4]
print( *list(map( lambda s: s+'\n', listC )), sep ='' )
# Out:
# Brazil
# Canada
# Euro
# Malaysia

# %%
for c in listC:
    dfusd[dfusd['Country'] == c].plot(kind = 'line', x = 'Date', y ='Exchange rate', label = c, ax = plt.gca())
plt.show()
