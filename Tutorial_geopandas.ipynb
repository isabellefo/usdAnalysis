# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

# %%
cidades = gpd.read_file('C:/TesteGeoPandas/UFEBRASIL.shp')

# %% [markdown]
# ### Importing and plotting the cities shapefile

# %%
cidades.plot()

# %%
cidades.plot(cmap = 'jet')

# %%
cidades.plot(cmap = 'jet', figsize = (10,10))

# %%
cidades.plot(cmap = 'spring', figsize = (10,10))
